# %% [markdown]
# ## LETS GROWMORE -LGM_VIP-SEPT2021-DATA ANALYTICS

# %% [markdown]
# ### Task:2- Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# ### Author:Ram kumar sah

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading data
data=pd.read_csv("C:/Users/kumar/OneDrive/Desktop/globalterrorismdb_0718dist.csv")
data
# Out:
#           Unnamed: 0  iyear  imonth  iday        approxdate  extended  \
# 0       1.970000e+11   1970       7     2               NaN         0
# 1       1.970000e+11   1970       0     0               NaN         0
# 2       1.970010e+11   1970       1     0               NaN         0
# 3       1.970010e+11   1970       1     0               NaN         0
# 4       1.970010e+11   1970       1     0               NaN         0
# ...              ...    ...     ...   ...               ...       ...
# 164730  2.016070e+11   2016       7    14  14-07-2016 00:00         0
# 164731  2.016070e+11   2016       7    14               NaN         0
# 164732  2.016070e+11   2016       7    14  14-07-2016 00:00         0
# 164733  2.016070e+11   2016       7    14  14-07-2016 00:00         0
# 164734  2.016070e+11   2016       7    14  14-07-2016 00:00         0
#
#        resolution  country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# ### EDA

# %%
data.shape    ## we have 164735 rows and 135 columns
# Out:
# (164735, 135)

# %%
data.columns.values
# Out:
# array(['Unnamed: 0', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
# Renaming some columns which we are gonna use.
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Targeted','nkill':'Killed',
                       'nwound':'No.of.Wounded','gname':'Gang','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data=data[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'No.of.Wounded','Targeted','Gang','Target_type','Weapon_type','Motive']]
data
# Out:
#         Year  Month  Day             Country     state  \
# 0       1970      7    2  Dominican Republic       NaN
# 1       1970      0    0              Mexico   Federal
# 2       1970      1    0         Philippines    Tarlac
# 3       1970      1    0              Greece    Attica
# 4       1970      1    0               Japan   Fukouka
# ...      ...    ...  ...                 ...       ...
# 164730  2016      7   14                Iraq   Baghdad
# 164731  2016      7   14                Iraq  Al Anbar
# 164732  2016      7   14                Iraq  Al Anbar
# 164733  2016      7   14                Iraq  Al Anbar
# 164734  2016      7   14                Iraq  Al Anbar
#
#                              Region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# 2                    Southeast Asia        Unknown  15.478598  120.599741
# ...

# %%
data.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# state               419
# Region                0
# city                434
# latitude           4478
# longitude          4479
# AttackType            0
# Killed             9343
# No.of.Wounded     14850
# Targeted            636
# Gang                  0
# Target_type           0
# Weapon_type           0
# Motive           116984
# dtype: int64

# %%
data.describe()
# Out:
#                 Year          Month            Day       latitude  \
# count  164735.000000  164735.000000  164735.000000  160257.000000
# mean     2001.197596       6.361362      15.443731      23.303293
# std        13.100467       3.385798       8.815961      18.995197
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1990.000000       3.000000       8.000000      11.081920
# 50%      2007.000000       6.000000      15.000000      31.355579
# 75%      2013.000000       9.000000      23.000000      34.774479
# max      2016.000000      12.000000      31.000000      74.633553
#
#           longitude         Killed  No.of.Wounded
# count  1.602560e+05  155392.000000  149885.000000
# mean  -5.123883e+02       2.381506       3.220956
# std    2.152926e+05      11.631851      37.550989
# min   -8.618590e+07       0.000000       0.000000
# 25%    1.231572e+00       0.000000       0.000000
# 50%    4.271509e+01       0.000000       0.000000
# ...

# %% [markdown]
# ### Visualization

# %%
#Most Attacked Country

print("Most Attacked Country:",data["Country"].value_counts().idxmax())
# Out:
# Most Attacked Country: Iraq

# %%
plt.subplots(figsize=(8,10))
sns.barplot(data['Country'].value_counts()[:10].values,data['Country'].value_counts()[:10].index,palette='cool_r')
plt.title('Top Countries Affected')
plt.xlabel('Count')
plt.ylabel('Countries')
plt.legend(labels = ['Top Countries Affected'])
plt.xticks(rotation= 0)
plt.show()

# %%
#Most Attacked City

print("Most Attacked City:",data["city"].value_counts().index[1])
# Out:
# Most Attacked City: Baghdad

# %%
plt.subplots(figsize=(8,10))
sns.barplot(data['state'].value_counts()[:10].values,data['state'].value_counts()[:10].index,palette='cool_r')
plt.title('Top State Affected')
plt.xlabel('Count')
plt.ylabel('State')
plt.legend(labels = ['Top State Affected'])
plt.xticks(rotation= 0)
plt.show()

# %%
#Most Attacked Region

print("Most Attacked Region:",data["Region"].value_counts().idxmax())
# Out:
# Most Attacked Region: Middle East & North Africa

# %%
#Area plot
pd.crosstab(data.Year,data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist activites by Region in each year')
plt.ylabel("Number of attacks")
plt.show()

# %%
#Most Attacked Gang

print("Most Attacked Gang:",data['Gang'].value_counts().index[1])
# Out:
# Most Attacked Gang: Taliban

# %%
plt.subplots(figsize=(8,10))
sns.barplot(data['Gang'].value_counts()[1:10].values,data['Gang'].value_counts()[1:10].index,palette='cool_r')
plt.title('Most Attacked Gang')
plt.xlabel('Count')
plt.ylabel('Gang Name')
plt.legend(labels = ['Top Gang'])
plt.xticks(rotation= 0)
plt.show()

# %%
print("Most Attack Types:",data['AttackType'].value_counts().idxmax())
# Out:
# Most Attack Types: Bombing/Explosion

# %%
attack_type = data.AttackType.value_counts()[:15]
attack_type
# Out:
# Bombing/Explosion                      80041
# Armed Assault                          39129
# Assassination                          18110
# Hostage Taking (Kidnapping)             9835
# Facility/Infrastructure Attack          9269
# Unknown                                 6014
# Unarmed Assault                          882
# Hostage Taking (Barricade Incident)      875
# Hijacking                                580
# Name: AttackType, dtype: int64

# %%
## Attack types 
plt.subplots(figsize=(12,6))
sns.barplot(attack_type.index,attack_type.values,palette="magma")
plt.title('Attack Types')
plt.xlabel('Types ot attacks')
plt.ylabel('Number of attacks')
plt.xticks(rotation= 90)
plt.show()

# %%
killData = data.loc[:,'Killed']
print('Number of people killed by terror attack:', int(sum(killData.dropna())))# drop the NaN values
# Out:
# Number of people killed by terror attack: 370067

# %%
m= data['Year'].value_counts(dropna = False).sort_index()
n = data['Year'].unique()
plt.figure(figsize = (18,10))
sns.barplot(x = n,y =m)
plt.xticks(rotation = 80)
plt.ylabel('Attack Year')
plt.legend(labels = ['Number of Attacks each year'])
plt.xlabel('Number of Attacks each year')
plt.title('Attack_of_Years')
# Out:
# Text(0.5, 1.0, 'Attack_of_Years')

# %% [markdown]
# ### Conclusion:-
#
# 1. Country with most attacks: Iraq
# 2. City with most attacks: Baghdad
# 3. Region with the most attacks: Middle East & North Africa
# 4. Year with the most attacks: 2014
# 5. Group with the most attacks: Taliban
# 6. Most Attack Types: Bombing/Explosion
